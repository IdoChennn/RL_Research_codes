# %%
import matplotlib.pyplot as plt # pip install matplotlib
import numpy as np

acc = [[43.6, 54.96, 61.69], [64.89, 66.39], [66.23, 67.54, 67.64], [67.71], [67.91, 68.37, 67.85, 68.01, 68.02, 67.72, 67.58, 67.71, 67.46], [67.73, 67.76]]

mu = [[ '0.01', '0.01'], ['0.01', '1.61'], ['1.61', '0.99', '0.01'], ['0.01'], ['0.01', '0.01', '0.01', '0.01', '0.01', '0.64', '0.36', '0.46', '1.48'], ['1.48', '1.61']]

# convert acc to 1d list
acc = [item for sublist in acc for item in sublist]
mu = [item for sublist in mu for item in sublist]

#
plt.figure(figsize=(15, 7),facecolor='white')
plt.title('Accuracies during RL',fontsize=25,color='black')
plt.plot(acc, label='Accuracy', color="black", linestyle="dashed", linewidth=4)
plt.xticks(np.arange(0, len(acc), 1),fontsize=25,color='black')
plt.yticks(fontsize=20,color='black')
ax = plt.gca()
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_facecolor('white')
plt.show()


plt.figure(figsize=(15, 7),facecolor='white')
plt.title('Mu during RL',fontsize=25,color='black')
plt.plot(mu, label='Mu', color="black", linestyle="dashed", linewidth=4)
plt.xticks(np.arange(0, len(mu), 1),fontsize=25,color='black')
plt.yticks(fontsize=20,color='black')
ax = plt.gca()
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_facecolor('white')
plt.show()

# %%
# acc =[[43.64, 54.97, 60.59, 63.91], [42.99, 54.2, 60.25, 63.2, 64.69, 65.99, 66.88, 66.95, 67.15, 67.12, 67.26, 67.07, 67.03, 67.09, 67.0], [45.54]]
# mu = [['0.01', '0.01', '0.02', '0.03'], ['0.03', '0.04', '0.05', '0.04', '0.05', '0.04', '0.03', '0.02', '0.03', '0.02', '0.02', '0.02', '0.03', '0.04', '0.05'], ['0.05']]
acc = [[45.35, 55.07, 59.75, 64.2, 66.11, 67.15], [43.94, 53.77, 60.72, 65.06, 66.0], [44.22, 54.71, 60.71, 64.91, 66.8, 67.24], [45.55, 55.85, 61.39, 63.73, 66.71, 67.38, 67.35], [45.38, 55.89, 61.34, 64.39, 65.72, 66.35], [42.49, 54.25, 60.51, 63.97, 64.51, 65.07], [45.77, 55.06, 61.03, 63.49, 66.39, 67.26], [43.62, 55.33, 61.72, 64.18, 66.06, 66.4, 67.08], [45.34, 55.89, 62.34, 65.52, 67.42, 68.01], [43.18, 55.08, 60.41, 63.34], [44.6, 54.7, 60.66, 64.28, 66.57, 66.79, 67.09, 67.5], [44.07, 54.78, 60.56, 64.54, 66.34], [46.44, 55.44, 61.39, 65.13, 66.33, 67.21, 67.5], [44.5, 54.73, 60.07], [44.86, 55.47], [46.05, 55.41, 59.83, 64.54, 66.4, 66.95, 67.23, 67.92, 68.12, 67.94], [45.48, 56.07, 61.9, 65.2, 66.05, 67.53]]
mu = [['0.10', '0.11', '0.12', '0.13', '0.12', '0.13'], ['0.13', '0.14', '0.15', '0.16', '0.17'], ['0.17', '0.18', '0.17', '0.16', '0.15', '0.16'], ['0.16', '0.17', '0.18', '0.19', '0.18', '0.19', '0.20'], ['0.20', '0.21', '0.22', '0.21', '0.20', '0.21'], ['0.21', '0.20', '0.21', '0.20', '0.21', '0.20'], ['0.20', '0.19', '0.18', '0.17', '0.18', '0.19'], ['0.19', '0.20', '0.19', '0.18', '0.19', '0.18', '0.17'], ['0.17', '0.16', '0.17', '0.18', '0.19', '0.18'], ['0.18', '0.19', '0.20', '0.21'], ['0.21', '0.22', '0.23', '0.22', '0.21', '0.20', '0.21', '0.20'], ['0.20', '0.19', '0.18', '0.19', '0.20'], ['0.20', '0.19', '0.18', '0.19', '0.18', '0.17', '0.18'], ['0.18', '0.17', '0.18'], ['0.18', '0.17'], ['0.17', '0.16', '0.15', '0.16', '0.15', '0.14', '0.15', '0.14', '0.15', '0.16'], ['0.16', '0.15', '0.16', '0.15', '0.14', '0.13']]
# convert acc to 1d list
acc = [sublist[len(sublist)-1] for sublist in acc if sublist[len(sublist)-1] > 60]
mu = [item for sublist in mu for item in sublist]

#
plt.figure(figsize=(15, 7),facecolor='white')
plt.title('Accuracies during RL',fontsize=25,color='black')
plt.plot(acc, label='Accuracy', color="black", linestyle="dashed", linewidth=4)
plt.xticks(np.arange(0, len(acc), 10),fontsize=25,color='black')
plt.yticks(fontsize=20,color='black')
ax = plt.gca()
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_facecolor('white')
plt.show()


plt.figure(figsize=(15, 7),facecolor='white')
plt.title('Mu during RL',fontsize=25,color='black')
plt.plot(mu, label='Mu', color="black", linestyle="dashed", linewidth=4)
plt.xticks(np.arange(0, len(mu), 10),fontsize=25,color='black')
plt.yticks(fontsize=20,color='black')
ax = plt.gca()
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_facecolor('white')
plt.show()

# %%
acc = [17.66, 33.02, 47.93, 55.07, 58.35, 21.36, 34.14, 48.55, 54.17, 58.19, 59.71, 61.88, 62.28, 62.82, 63.24, 63.18, 25.69, 37.28, 48.56, 54.85, 59.72, 60.49, 61.19, 62.1, 61.92]

#
plt.figure(figsize=(15, 7),facecolor='white')
plt.title('Accuracies during RL',fontsize=25,color='black')
plt.plot(acc, label='Accuracy', color="black", linestyle="dashed", linewidth=4)
plt.xticks(np.arange(0, len(acc), 10),fontsize=25,color='black')
plt.yticks(fontsize=20,color='black')
ax = plt.gca()
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_facecolor('white')
plt.show()
